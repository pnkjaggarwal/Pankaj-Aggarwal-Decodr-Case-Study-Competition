# %%
# importing basic libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('Ionosphere.csv')    # data loading and top 5 rows
data.head()
# Out:
#    V1  V2       V3       V4       V5       V6       V7       V8       V9  \
# 0   1   0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 1   1   0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 2   1   0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 3   1   0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 4   1   0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
#
#        V10      V11      V12      V13      V14      V15      V16      V17  \
# 0  0.03760  0.85243 -0.17755  0.59755 -0.44945  0.60536 -0.38223  0.84356
# 1 -0.04549  0.50874 -0.67743  0.34432 -0.69707 -0.51685 -0.97515  0.05499
# 2  0.01198  0.73082  0.05346  0.85443  0.00827  0.54591  0.00299  0.83775
# 3  0.00000  0.00000  0.00000  0.00000  0.00000 -1.00000  0.14516  0.54094
# 4 -0.16399  0.52798 -0.20275  0.56409 -0.00712  0.34395 -0.27457  0.52940
#
#        V18      V19      V20      V21      V22      V23      V24      V25  \
# ...

# %%
data.shape    # file size rows, columns
# Out:
# (351, 35)

# %%
data.info()     # data info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 35 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V1      351 non-null    int64
#  1   V2      351 non-null    int64
#  2   V3      351 non-null    float64
#  3   V4      351 non-null    float64
#  4   V5      351 non-null    float64
#  5   V6      351 non-null    float64
#  6   V7      351 non-null    float64
#  7   V8      351 non-null    float64
#  8   V9      351 non-null    float64
#  9   V10     351 non-null    float64
#  10  V11     351 non-null    float64
#  11  V12     351 non-null    float64
#  12  V13     351 non-null    float64
#  13  V14     351 non-null    float64
#  14  V15     351 non-null    float64
#  15  V16     351 non-null    float64
#  16  V17     351 non-null    float64
#  17  V18     351 non-null    float64
#  18  V19     351 non-null    float64
#  19  V20     351 non-null    float64
#  20  V21     351 non-null    float64
# ...

# %%
data.describe().T       # data statistical info
# Out:
#        count      mean       std  min       25%      50%       75%  max
# V1     351.0  0.891738  0.311155  0.0  1.000000  1.00000  1.000000  1.0
# V2     351.0  0.000000  0.000000  0.0  0.000000  0.00000  0.000000  0.0
# V3     351.0  0.641342  0.497708 -1.0  0.472135  0.87111  1.000000  1.0
# V4     351.0  0.044372  0.441435 -1.0 -0.064735  0.01631  0.194185  1.0
# V5     351.0  0.601068  0.519862 -1.0  0.412660  0.80920  1.000000  1.0
# V6     351.0  0.115889  0.460810 -1.0 -0.024795  0.02280  0.334655  1.0
# V7     351.0  0.550095  0.492654 -1.0  0.211310  0.72873  0.969240  1.0
# V8     351.0  0.119360  0.520750 -1.0 -0.054840  0.01471  0.445675  1.0
# V9     351.0  0.511848  0.507066 -1.0  0.087110  0.68421  0.953240  1.0
# V10    351.0  0.181345  0.483851 -1.0 -0.048075  0.01829  0.534195  1.0
# V11    351.0  0.476183  0.563496 -1.0  0.021120  0.66798  0.957895  1.0
# V12    351.0  0.155040  0.494817 -1.0 -0.065265  0.02825  0.482375  1.0
# ...

# %%
data.isna().sum()      # no null values
# Out:
# V1       0
# V2       0
# V3       0
# V4       0
# V5       0
# V6       0
# V7       0
# V8       0
# V9       0
# V10      0
# V11      0
# V12      0
# V13      0
# V14      0
# V15      0
# V16      0
# V17      0
# V18      0
# V19      0
# V20      0
# V21      0
# V22      0
# V23      0
# V24      0
# V25      0
# V26      0
# V27      0
# V28      0
# V29      0
# V30      0
# V31      0
# V32      0
# V33      0
# V34      0
# Class    0
# dtype: int64

# %%
categorical = data.select_dtypes(include = ['int64'])        # choosing only features with 0,1 values

# %%
categorical.head()
# Out:
#    V1  V2  Class
# 0   1   0      1
# 1   1   0      0
# 2   1   0      1
# 3   1   0      0
# 4   1   0      1

# %%
continuous = data.loc[:,'V3':'Class']        # choosing continuous values

# %%
continuous.head()
# Out:
#         V3       V4       V5       V6       V7       V8       V9      V10  \
# 0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000  0.03760
# 1  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000 -0.04549
# 2  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965  0.01198
# 3  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000  0.00000
# 4  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152 -0.16399
#
#        V11      V12      V13      V14      V15      V16      V17      V18  \
# 0  0.85243 -0.17755  0.59755 -0.44945  0.60536 -0.38223  0.84356 -0.38542
# 1  0.50874 -0.67743  0.34432 -0.69707 -0.51685 -0.97515  0.05499 -0.62237
# 2  0.73082  0.05346  0.85443  0.00827  0.54591  0.00299  0.83775 -0.13644
# 3  0.00000  0.00000  0.00000  0.00000 -1.00000  0.14516  0.54094 -0.39330
# 4  0.52798 -0.20275  0.56409 -0.00712  0.34395 -0.27457  0.52940 -0.21780
#
# ...

# %%
for i in categorical.columns:
    plt.figure(figsize=[10,5])
    sns.countplot(x=i, hue='Class', data= data)
    plt.xlabel(i)
    plt.tick_params('x', rotation=45)
    plt.show()
    print(data.groupby(['Class',i])[i].count())
    print(data[i].isna().sum())
# Out:
# Class  V1
# 0      0      38
#        1      88
# 1      1     225
# Name: V1, dtype: int64
# 0
# Class  V2
# 0      0     126
# 1      0     225
# Name: V2, dtype: int64
# 0
# Class  Class
# 0      0        126
# 1      1        225
# Name: Class, dtype: int64
# 0

# %% [markdown]
# - V2 have all 0 values, no use

# %%
data.drop('V2', axis =1, inplace=True)

# %%
plt.figure(figsize=[20,10])
sns.heatmap(continuous.corr(), annot=True)
plt.show()

# %% [markdown]
# - As we can see there are lots of correlated features will take care of it by VIF

# %%
X = data.loc[:, 'V1':'V34']                  #  feature variables
y = data['Class']                             # target variable
X.head()
# Out:
#    V1       V3       V4       V5       V6       V7       V8       V9      V10  \
# 0   1  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000  0.03760
# 1   1  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000 -0.04549
# 2   1  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965  0.01198
# 3   1  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000  0.00000
# 4   1  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152 -0.16399
#
#        V11      V12      V13      V14      V15      V16      V17      V18  \
# 0  0.85243 -0.17755  0.59755 -0.44945  0.60536 -0.38223  0.84356 -0.38542
# 1  0.50874 -0.67743  0.34432 -0.69707 -0.51685 -0.97515  0.05499 -0.62237
# 2  0.73082  0.05346  0.85443  0.00827  0.54591  0.00299  0.83775 -0.13644
# 3  0.00000  0.00000  0.00000  0.00000 -1.00000  0.14516  0.54094 -0.39330
# 4  0.52798 -0.20275  0.56409 -0.00712  0.34395 -0.27457  0.52940 -0.21780
#
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
# splitting the data 
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 0, stratify = y)

# %% [markdown]
# 1. Without feature selection

# %%
lreg.fit(x_train, y_train)   # fitting the data directly
# Out:
# LogisticRegression()

# %%
y_predict_train = lreg.predict(x_train)     
y_predict_test = lreg.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
train_accuracy = accuracy_score(y_train, y_predict_train)
test_accuracy = accuracy_score(y_test, y_predict_test)
train_accuracy, test_accuracy
# Out:
# (0.925, 0.8450704225352113)

# %% [markdown]
# - Accuracy is pretty good but lets try with feature selection also

# %% [markdown]
# 2. With Feature Selection

# %%
from sklearn.feature_selection import RFE
from statsmodels.stats.outliers_influence import variance_inflation_factor
lreg = LogisticRegression()
rfe = RFE(n_features_to_select=15, estimator=lreg)

# %%
rfe.fit(x_train, y_train)
# Out:
# RFE(estimator=LogisticRegression(), n_features_to_select=15)

# %%
pd.DataFrame(data = [x_train.columns, rfe.support_, rfe.ranking_]).T.sort_values(2).head(20)
# Out:
#       0      1  2
# 0    V1   True  1
# 29  V31   True  1
# 28  V30   True  1
# 25  V27   True  1
# 24  V26   True  1
# 20  V22   True  1
# 13  V15   True  1
# 8   V10   True  1
# 32  V34   True  1
# 5    V7   True  1
# 1    V3   True  1
# 2    V4   True  1
# 3    V5   True  1
# 6    V8   True  1
# 4    V6   True  1
# 9   V11  False  2
# 21  V23  False  3
# 16  V18  False  4
# 30  V32  False  5
# 23  V25  False  6

# %%
x_train = x_train[x_train.columns[rfe.support_]]

# %%
x_train.shape
# Out:
# (280, 15)

# %%
vif = pd.DataFrame()
vif['Features'] = x_train.columns
vif['VIF'] = [variance_inflation_factor(x_train.values, i) for i in range(x_train.shape[1])]
vif['VIF'] = round(vif['VIF'])
vif = vif.sort_values('VIF',ascending = False)
vif
# Out:
#    Features  VIF
# 5        V7  5.0
# 0        V1  4.0
# 1        V3  4.0
# 3        V5  4.0
# 8       V15  4.0
# 2        V4  2.0
# 4        V6  2.0
# 6        V8  2.0
# 10      V26  2.0
# 11      V27  2.0
# 12      V30  2.0
# 13      V31  2.0
# 14      V34  2.0
# 7       V10  1.0
# 9       V22  1.0

# %%
x_train.drop('V7', axis =1, inplace=True)

# %%
vif = pd.DataFrame()
vif['Features'] = x_train.columns
vif['VIF'] = [variance_inflation_factor(x_train.values, i) for i in range(x_train.shape[1])]
vif['VIF'] = round(vif['VIF'])
vif = vif.sort_values('VIF',ascending = False)
vif
# Out:
#    Features  VIF
# 0        V1  4.0
# 1        V3  4.0
# 3        V5  4.0
# 7       V15  3.0
# 2        V4  2.0
# 4        V6  2.0
# 5        V8  2.0
# 9       V26  2.0
# 10      V27  2.0
# 11      V30  2.0
# 12      V31  2.0
# 13      V34  2.0
# 6       V10  1.0
# 8       V22  1.0

# %%
x_test = x_test[x_train.columns]

# %%
lreg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_predict_train = lreg.predict(x_train)
y_predict_test = lreg.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
train_accuracy = accuracy_score(y_train, y_predict_train)
test_accuracy = accuracy_score(y_test, y_predict_test)

# %%
train_accuracy, test_accuracy
# Out:
# (0.9142857142857143, 0.8309859154929577)

# %%
y_prob_train = lreg.predict_proba(x_train)[:,1]
y_prob_test = lreg.predict_proba(x_test)[:,1]

# %%
matrix = classification_report(y_test, y_predict_test)

# %%
print(matrix)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.60      0.71        25
#            1       0.81      0.96      0.88        46
#
#     accuracy                           0.83        71
#    macro avg       0.85      0.78      0.80        71
# weighted avg       0.84      0.83      0.82        71

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc

# %%
fpr, tpr, thresholds = roc_curve(y_train, y_prob_train)

# %%
model_score = roc_auc_score(y_test, y_prob_test)

# %%
model_score
# Out:
# 0.9165217391304348

# %%
plt.plot(fpr, tpr, color = 'b', label='Roc Curve (area = %2f)' %model_score)
plt.plot([0,1], [0,1], 'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.title('ROC Example')
plt.legend(loc='lower right')  # to show the area in lower right
plt.show()

# %%
i = np.arange(len(tpr))
optimal_threshold = pd.DataFrame({'fpr' : pd.Series(fpr, index = i), 'tpr' : pd.Series(tpr, index = i), '1-fpr' : pd.Series(1-fpr, index=i),
                                  'tf' : pd.Series(tpr-(1-fpr), index=i),'threshold' : pd.Series(thresholds.round(2), index=i)})
abs(optimal_threshold).sort_values('tf', ascending=True).head()
# Out:
#          fpr       tpr     1-fpr        tf  threshold
# 23  0.118812  0.877095  0.881188  0.004093       0.74
# 22  0.099010  0.877095  0.900990  0.023895       0.74
# 21  0.099010  0.871508  0.900990  0.029482       0.74
# 20  0.089109  0.871508  0.910891  0.039383       0.76
# 24  0.118812  0.927374  0.881188  0.046186       0.65

# %%
from sklearn.preprocessing import binarize
y_predict_test = binarize(y_prob_test.reshape(-1,1), 0.74)

# %%
accuracy_score(y_predict_1, y_test)
# Out:
# 0.8450704225352113

# %%
plt.plot(optimal_threshold.set_index('threshold').tpr)
plt.plot(optimal_threshold.set_index('threshold')['1-fpr'])
plt.show()

# %%
print(classification_report(y_test, y_predict_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.80      0.78        25
#            1       0.89      0.87      0.88        46
#
#     accuracy                           0.85        71
#    macro avg       0.83      0.83      0.83        71
# weighted avg       0.85      0.85      0.85        71

# %%
result = pd.DataFrame(data = [y_test.values,y_predict_test.flatten()]).T
result.columns= ['Actual', 'Predicted']

# %%
result
# Out:
#     Actual  Predicted
# 0      0.0        1.0
# 1      1.0        1.0
# 2      1.0        0.0
# 3      0.0        1.0
# 4      1.0        1.0
# 5      0.0        0.0
# 6      1.0        1.0
# 7      1.0        0.0
# 8      0.0        1.0
# 9      0.0        0.0
# 10     0.0        0.0
# 11     0.0        0.0
# 12     1.0        1.0
# 13     0.0        0.0
# 14     1.0        1.0
# 15     1.0        1.0
# 16     1.0        1.0
# 17     0.0        0.0
# 18     1.0        1.0
# 19     1.0        1.0
# 20     1.0        0.0
# 21     1.0        1.0
# 22     1.0        0.0
# 23     0.0        0.0
# 24     1.0        1.0
# 25     0.0        0.0
# 26     1.0        1.0
# 27     0.0        0.0
# 28     0.0        0.0
# 29     0.0        1.0
# 30     1.0        1.0
# 31     1.0        1.0
# 32     1.0        1.0
# 33     0.0        0.0
# 34     1.0        1.0
# 35     0.0        0.0
# 36     1.0        1.0
# 37     1.0        1.0
# 38     1.0        1.0
# 39     0.0        0.0
# ...

# %% [markdown]
# Conclusion -
#     1. Train score - 91.4, Test score - 83.1
#     2. After reducing the feature from 30 to 15 there's no significant change in accuracy, so I will use feature extraction because of less computational power consumption and less complexity.
#     3. I tried to reduc features to 20, 25 as well but performance was also approx same.
#     4. Better accuracy can be achieved with ensemble techiniques but due to limited time cant explore those methods.
#     5. We will use threshold frequency as 0.74 as tf value is lowest, other metrics are significantly better in classification report and there is no significant change in accuracy.
